# %% [raw]
#                                           Assingnment bokeh

# %% [raw]
# Q1. How can you create a Bokeh plot using Python code?

# %% [raw]
# """ 1..Import the necessary modules from the Bokeh library.
#   2.Create a figure() object. This object represents the plot itself.
#   3.Add glyphs to the figure. Glyphs are the visual elements that make up the plot, such as lines, circles, and bars.
#   4.Set the properties of the figure and glyphs. This includes things like the title, axis labels, and colors.
#   5.Show the plot.
#  example:-   """
# from bokeh.plotting import figure, show
#
# x = [1, 2, 3, 4, 5]
# y = [6, 7, 2, 4, 5]
#
# p = figure(title="My Line Plot", x_axis_label="x", y_axis_label="y")
#
# p.line(x, y, legend_label="Line", line_width=2)
# show(p)
#
# """This code will create a line plot with the data points (1, 6), (2, 7), (3, 2), (4, 4), and (5, 5).
# The title of the plot is "My Line Plot" and the axis labels are "x" and "y". The line is also 2 pixels thick.
#
# """
# 1.Use a consistent color scheme.
# 2.Use clear and concise labels.
# 3.Use a well-defined title.
# 4.Use a legend to identify different lines or bars.
# 5.Add annotations to highlight important points.
# 6.Use gridlines to make the plot easier to read.
# 7.Experiment with different plot types to find the one that best suits your data.

# %% [raw]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %%
"""In Bokeh, glyphs are the visual markers that represent data points on a plot.
   They can be thought of as the graphical elements that display your data, 
   such as circles, squares, lines, bars, and more. Glyphs are added to a Bokeh plot to visually represent
   the data you want to visualize.
example:-"""
from bokeh.plotting import figure, show
import numpy as np

# Generate example data
x = np.random.random(100)
y = np.random.random(100)

p = figure(title="Scatter Plot with Circles", x_axis_label="X-axis", y_axis_label="Y-axis")

p.circle(x, y, size=10, color="blue", alpha=0.5)

show(p)
""">We imported the necessary modules (figure and show) from Bokeh and generated example data using NumPy.
>We created a figure using the figure function, setting the plot title and axis labels.
>We added circles as glyphs to the figure using the circle method. The x, y, size, color, and alpha parameters define the position, size, color, and transparency of the circles.
>Finally, we displayed the plot using the show function.
Here are some other common types of glyphs you can use in Bokeh:

>line: Create line plots.
>square, triangle, diamond: Shapes other than circles for scatter plots.
>bar, vbar, hbar: Create vertical or horizontal bar plots.
>patch: Create filled polygons."""

# %% [raw]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
"""You can customize various aspects of a Bokeh plot, including axes, titles, legends,
colors, and more, using the available configuration options.
Here's how you can customize the appearance of a Bokeh plot:
Customizing Axes:
    You can customize axes labels, ticks, ranges, and more using properties provided by the figure object
from bokeh.plotting import figure, show
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

p = figure(title="Customizing Axes", x_axis_label="X-axis", y_axis_label="Y-axis")


p.xaxis.major_label_orientation = "vertical"
p.y_range.start = -1.2
p.y_range.end = 1.2

p.line(x, y)

show(p)
Adding Titles:
You can set the title of the plot using the title attribute of the figure object.

python
Copy code
p = figure(title="Custom Title")
Customizing Legends:
You can add legends to differentiate between different data series. Legends can be customized in terms of placement, title, and appearance.

python
Copy code
p = figure(title="Custom Legend")
p.line(x, y, legend_label="Sin(x)", line_color="blue")
p.circle(x, y, legend_label="Data Points", fill_color="red", size=6)
p.legend.title = "Legend Title"
p.legend.location = "top_left"
p.legend.label_text_font_size = "12pt"
Customizing Colors:
You can customize colors for lines, fill areas, and text using named colors or hexadecimal color codes.

python
Copy code
p.line(x, y, line_color="green", line_width=2)
p.circle(x, y, fill_color="orange", size=8)
p.title.text_color = "navy"
Customizing Fonts and Text:
You can customize the font styles and sizes of titles, labels, and other text elements.

python
Copy code
p.title.text_font = "times"
p.title.text_font_style = "italic"
p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.major_label_text_font_size = "10pt"
Background and Grid Lines:
You can customize the appearance of background and grid lines.

python
Copy code
p.background_fill_color = "lightgrey"
p.grid.grid_line_color = "white"    """
# Out:
# 'You can customize various aspects of a Bokeh plot, including axes, titles, legends,\ncolors, and more, using the available configuration options.\nHere\'s how you can customize the appearance of a Bokeh plot:\nCustomizing Axes:\n    You can customize axes labels, ticks, ranges, and more using properties provided by the figure object\nfrom bokeh.plotting import figure, show\nimport numpy as np\n\nx = np.linspace(0, 10, 100)\ny = np.sin(x)\n\np = figure(title="Customizing Axes", x_axis_label="X-axis", y_axis_label="Y-axis")\n\n\np.xaxis.major_label_orientation = "vertical"\np.y_range.start = -1.2\np.y_range.end = 1.2\n\np.line(x, y)\n\nshow(p)\nAdding Titles:\nYou can set the title of the plot using the title attribute of the figure object.\n\npython\nCopy code\np = figure(title="Custom Title")\nCustomizing Legends:\nYou can add legends to differentiate between different data series. Legends can be customized in terms of placement, title, and appearance.\n\npython\nCopy code\np = figu
# ...

# %% [raw]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
#     real time?

# %% [raw]
# A Bokeh server is a feature of the Bokeh library that allows you to create interactive web applications
#       with real-time updates.
#      With Bokeh server, you can build dynamic and interactive plots and applications that respond to user
#      input or changing data sources without needing to repeatedly generate and display new static plots.
#
#
# Setup and Import:-
# First, you need to import the necessary modules and functions from Bokeh and set up your data and plot as usual.
#
# Create a Function to Update Data:-
# In a Bokeh server application, you define a function that updates the data you want to visualize.
# This function is typically called in response to user interactions or timers.
#
# Create a Bokeh Document:-
# You create a Bokeh Document object that holds your plot and any other components you want to display.
#
# Define the Layout:-
# You define the layout of your document, which includes the plot and any other widgets or components you want to interact with.
# This layout can include widgets like sliders, buttons, text inputs, etc.
#
# Add Callbacks:-
# You attach callbacks to the widgets or other user interface elements.
# Callbacks are functions that get executed when an event, such as a button click or slider change, occurs.
#
# Start the Bokeh Server Application:-
# Finally, you start the Bokeh server application using the bokeh serve command with the script name as an argument.
# This starts a local server that serves your interactive plot/application.
#
#
# from bokeh.plotting import figure, curdoc
# from bokeh.models import Slider
#
# x = [1, 2, 3, 4, 5]
# y = [6, 7, 2, 4, 5]
#
#
# p = figure(title="Interactive Scatter Plot", tools="pan,box_zoom,reset")
#
# scatter = p.circle(x, y, size=15, color="blue", alpha=0.5)
#
#
# slider = Slider(start=0, end=10, step=1, value=0, title="Shift")
#
# def update_data(attrname, old, new):
#     shift = slider.value
#     new_x = [val + shift for val in x]
#     scatter.data_source.data['x'] = new_x
#
# slider.on_change('value', update_data)
#
# layout = column(p, slider)
#
# curdoc().add_root(layout)

# %% [raw]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [raw]
# Embedding a Bokeh plot into a web page or dashboard using Flask or Django involves creating a
# web application that combines the capabilities of the web framework (Flask or Django)
# with the interactive plots generated using Bokeh. Here's a general outline of how you can achieve this
#
# Flask:
#
# Install Flask and Bokeh:
# Make sure you have Flask and Bokeh installed:
# pip install Flask bokeh
#
# Create Flask Application:
# Create a Flask application and define routes to render the templates with embedded Bokeh plots.
#
# from flask import Flask, render_template
# from bokeh.embed import server_document
#
# app = Flask(__name__)
#
# @app.route('/')
# def index():
#     bokeh_script = server_document(url='http://localhost:5006/your_bokeh_app')
#     return render_template('index.html', bokeh_script=bokeh_script)
#
# if __name__ == '__main__':
#     app.run()
#
# Create a Bokeh Application:
# Create a separate Bokeh application using Bokeh server. Save this in a file named your_bokeh_app.py.
#
# from bokeh.plotting import figure
# from bokeh.server.server import Server
# from tornado.ioloop import IOLoop
#
# def modify_doc(doc):
#     p = figure(title="Embedded Bokeh Plot", tools="pan,box_zoom,reset")
#     # Create your plot here
#
#     doc.add_root(p)
#
# server = Server({'/your_bokeh_app': modify_doc}, io_loop=IOLoop(), allow_websocket_origin=["localhost:5000"])
# server.start()
#
# if __name__ == '__main__':
#     server.io_loop.start()
#
# Create HTML Template:
# Create an HTML template (e.g., templates/index.html) that will be rendered by Flask.
# Embed the Bokeh plot using the bokeh_script variable.
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Bokeh Embedded Plot</title>
# </head>
# <body>
#     <h1>Embedded Bokeh Plot</h1>
#     {{ bokeh_script | safe }}
# </body>
# </html>
# Django:
#
# Install Django and Bokeh:
# Make sure you have Django and Bokeh installed:
#
# bash
# Copy code
# pip install Django bokeh
# Create a Django Project and App:
# Create a Django project and app, and set up the necessary configurations.
#
# Create Views and Templates:
# Define views that render HTML templates with embedded Bokeh plots.
#
# Create a Bokeh Application:
# Follow a similar process as mentioned for Flask to create a Bokeh application using Bokeh server.
#
# Embed Bokeh Script in Template:
# Embed the Bokeh plot script in your Django HTML template, similar to how it was done for Flask.
#
# Configure URL Routing:
# Configure the URL routing in Django's urls.py to map URLs to your views.
